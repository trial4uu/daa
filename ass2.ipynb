# %%
import pandas as pd
import numpy as ny
import seaborn as sns

# %%
df=pd.read_csv("dataset_Facebook.csv",delimiter=";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
subset1=df[['Type','Category','Post Month']]
print(subset1.head())
# Out:
#      Type  Category  Post Month
# 0   Photo         2          12
# 1  Status         2          12
# 2   Photo         3          12
# 3   Photo         2          12
# 4   Photo         2          12

# %%
subset2=df[['comment','like','Type']]
print(subset2.head())
# Out:
#    comment    like    Type
# 0        4    79.0   Photo
# 1        5   130.0  Status
# 2        0    66.0   Photo
# 3       58  1572.0   Photo
# 4       19   325.0   Photo

# %%
df1=df[['Type','Category']]
df2=df[['Post Month','Post Weekday']]

# %%
merged=pd.concat([df1,df2], axis=1)
print(merged.head())
# Out:
#      Type  Category  Post Month  Post Weekday
# 0   Photo         2          12             4
# 1  Status         2          12             3
# 2   Photo         3          12             3
# 3   Photo         2          12             2
# 4   Photo         2          12             2

# %%
sorted=df.sort_values(by=['like'],ascending=False)
sorted.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 379   1.0                     105632                           147918
# 349   0.0                      81856                           124753
# 168   0.0                      41984                            68290
# 3     1.0                      50128                            87991
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
merged.T
# Out:
#                 0       1      2      3      4       5      6      7    \
# Type          Photo  Status  Photo  Photo  Photo  Status  Photo  Photo
# Category          2       2      3      2      2       2      3      3
# Post Month       12      12     12     12     12      12     12     12
# Post Weekday      4       3      3      2      2       1      1      7
#
#                  8      9    ...    490    491   492    493    494    495  \
# Type          Status  Photo  ...  Photo  Photo  Link  Photo  Photo  Photo
# Category           2      3  ...      3      3     1      3      3      3
# Post Month        12     12  ...      1      1     1      1      1      1
# Post Weekday       7      6  ...      6      6     5      1      7      7
#
#                 496    497    498    499
# Type          Photo  Photo  Photo  Photo
# Category          2      1      3      2
# Post Month        1      1      1      1
# Post Weekday      5      5      4      4
#
# [4 rows x 500 columns]

# %%
transposed=merged.transpose()
transposed.head()
# Out:
#                 0       1      2      3      4       5      6      7    \
# Type          Photo  Status  Photo  Photo  Photo  Status  Photo  Photo
# Category          2       2      3      2      2       2      3      3
# Post Month       12      12     12     12     12      12     12     12
# Post Weekday      4       3      3      2      2       1      1      7
#
#                  8      9    ...    490    491   492    493    494    495  \
# Type          Status  Photo  ...  Photo  Photo  Link  Photo  Photo  Photo
# Category           2      3  ...      3      3     1      3      3      3
# Post Month        12     12  ...      1      1     1      1      1      1
# Post Weekday       7      6  ...      6      6     5      1      7      7
#
#                 496    497    498    499
# Type          Photo  Photo  Photo  Photo
# Category          2      1      3      2
# Post Month        1      1      1      1
# Post Weekday      5      5      4      4
#
# [4 rows x 500 columns]

# %%
df.shape
# Out:
# (500, 19)

# %%
import numpy as ny

arr=ny.array(df[['Post Month','Post Weekday']].head(6))
reshaped=arr.reshape(3,4)
print(reshaped)
# Out:
# [[12  4 12  3]
#  [12  3 12  2]
#  [12  2 12  1]]
